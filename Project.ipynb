# %% [markdown]
# <a href="https://colab.research.google.com/github/Vamsikrishna1804/Vamsikrishnabharghava_INFO5731_Spring2021/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('dtrump_cleaneddata.csv')
df
# Out:
#       Unnamed: 0       created_at  ...                   country collected_at
# 0              2  10/15/2020 0:00  ...  United States of America      00:00.7
# 1              3  10/15/2020 0:00  ...                       NaN      00:01.1
# 2              4  10/15/2020 0:00  ...  United States of America      00:01.5
# 3              5  10/15/2020 0:00  ...  United States of America      00:01.9
# 4              7  10/15/2020 0:00  ...  United States of America      00:02.6
# ...          ...              ...  ...                       ...          ...
# 1188        1394  10/15/2020 1:29  ...                       NaN      08:48.8
# 1189        1395  10/15/2020 1:29  ...                       NaN      08:48.5
# 1190        1396  10/15/2020 1:29  ...                       NaN      08:49.2
# 1191        1398  10/15/2020 1:30  ...  United States of America      08:49.6
# 1192        1399  10/15/2020 1:30  ...                       NaN      08:50.3
#
# [1193 rows x 6 columns]

# %%
df[pd.to_numeric(df.tweet, errors='coerce').isnull()]
# Out:
#       Unnamed: 0       created_at  ...                   country collected_at
# 0              2  10/15/2020 0:00  ...  United States of America      00:00.7
# 1              3  10/15/2020 0:00  ...                       NaN      00:01.1
# 2              4  10/15/2020 0:00  ...  United States of America      00:01.5
# 3              5  10/15/2020 0:00  ...  United States of America      00:01.9
# 4              7  10/15/2020 0:00  ...  United States of America      00:02.6
# ...          ...              ...  ...                       ...          ...
# 1188        1394  10/15/2020 1:29  ...                       NaN      08:48.8
# 1189        1395  10/15/2020 1:29  ...                       NaN      08:48.5
# 1190        1396  10/15/2020 1:29  ...                       NaN      08:49.2
# 1191        1398  10/15/2020 1:30  ...  United States of America      08:49.6
# 1192        1399  10/15/2020 1:30  ...                       NaN      08:50.3
#
# [1193 rows x 6 columns]

# %%
#Removing special characters and punctuations
df['Special Characters removal']=df['tweet'].str.replace('[!-;:,<>./?@#$%^&*_~{}]','')
#Remove numbers
df['Remove numbers']=df['tweet'].str.replace('\d','')
#Stopwords removal
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop=stopwords.words('english') 
df['Stopwords removal']=df['tweet'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
#Lower casing
df['Lower casing']=df['tweet'].apply(lambda x: " ".join(x.lower() for x in x.split()))
#stemming
from nltk.stem import PorterStemmer
st=PorterStemmer()
df['stemming']=df['tweet'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
#Lemmatization
import nltk
from textblob import Word
nltk.download('wordnet')
df['Lemmatization']=df['tweet'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#       Unnamed: 0  ...                                      Lemmatization
# 0              2  ...  #Trump: As a student I used to hear for years,...
# 1              3  ...  2 hour since last tweet from #Trump! Maybe he ...
# 2              4  ...  You get a tie! And you get a tie! #Trump ‘s ra...
# 3              5  ...  @CLady62 Her 15 minute were over long time ago...
# 4              7  ...  @DeeviousDenise @realDonaldTrump @nypost There...
# ...          ...  ...                                                ...
# 1188        1394  ...  Politics ha become 100% corruption because gov...
# 1189        1395  ...  #Trump #BidenTownHall #BidenHarris #Biden #Bur...
# 1190        1396  ...  @BrunoStagno And let not forget... #MBS silenc...
# ...
